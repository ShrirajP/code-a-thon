# %%
d={"name":[],"Marks":[],"IQ":[]}
while True:
   
    t=[]

    print("Enter your name")
    s=input(" ")
    d["name"].append(s)
    print("Number of attempt")
    n=int(input(" "))

    if n == 1:
    #    while True:
            print("Apptitude\nIt was Sunday on Jan 1, 2006. What was the day of the week Jan 1, 2010?")
            a = input(" ")
            if a == "friday":
                t.append(10)
            else:
                t.append(0)
            print("English\nHow many articles are there in english grammar?")
            e = int(input(""))
            if e == 3:
                t.append(10)
            else:
                t.append(0)
            print("Math\nHow many sides Triangle Have?")
            m = int(input(""))

            if m == 3:
                t.append(10)
            else:
                t.append(0)
            print("G.K\nWhat is the Shape of Earth ellipsoid or Round?")
            g = input("")
            if g == "ellipsoid":
                t.append(10)
            else:
                t.append(0)
    #        break


    else:
        print("sorry you can only atempt once")
        break
    p = sum(t)
    #print("Total ",p)

    if p == 20:
        t.append(2)
    elif p == 30:
        t.append(5)
    elif p == 40:
        t.append(10)

    b = sum(t)
    #print("Total after adding Bouns ",b)
    d["Marks"].append(b)

    if b >= 10 and b < 22:
        print("Your IQ LEVEL IS below average\nTotal:- {}\nTotal with bonus:- {}".format(p,b))
        d["IQ"].append("Your IQ LEVEL IS below average")
    elif b >= 22 and b < 35:
        print("your iq level is average\nTotal:- {}\nTotal with bonus:- {}".format(p,b))
        d["IQ"].append("your iq level is average")
    elif b >= 35 and b < 40:
        print("you are intelligent\nTotal:- {}\nTotal with bonus:- {}".format(p,b))
        d["IQ"].append("you are intelligent")
    elif b >= 40:
        print("you are genius\nTotal:- {}\nTotal with bonus:- {}".format(p,b))
        d["IQ"].append("you are genius")
    else:
        print("you need to re appear\nTotal:- {}\nTotal with bonus:- {}".format(p,b))
        d["IQ"].append("you need to re appear")


    #print(d)


    
    
    print("Do you want to exit?")
    x = input("yes or no")
    if x == "yes":
        break
    else:
        print("invalid")
# Out:
# Enter your name
#  shriraj
# Number of attempt
#  1
# Apptitude
# It was Sunday on Jan 1, 2006. What was the day of the week Jan 1, 2010?
#  friday
# English
# How many articles are there in english grammar?
# 3
# Math
# How many sides Triangle Have?
# 3
# G.K
# What is the Shape of Earth ellipsoid or Round?
# round
# you are intelligent
# Total:- 30
# Total with bonus:- 35
# Do you want to exit?
# yes or nono
# invalid
# Enter your name
#  omkar
# Number of attempt
#  2
# sorry you can only atempt once
